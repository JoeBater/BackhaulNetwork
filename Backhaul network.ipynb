# %% [markdown]
# # Backhaul network

# %%
# import libraries
import pandas as pd
import numpy as np

import tkinter as tk

# %%
# set the nodes with random locations
nodes = pd.DataFrame(columns=['x', 'y', 'connects', 'path'], dtype=object)
for i in range(100):
    nodes = nodes.append({'x':np.random.randint(1, 1399), 'y':np.random.randint(1, 699), 'connects':0, 
                          'path':[0]}, ignore_index=True)

# declare a blank set of links
links = np.zeros(shape=(len(nodes), len(nodes)))

# declare a blank set of capacities
capacities = np.zeros(shape=(len(nodes), len(nodes)))

# %%
nodes
# Out:
#        x    y connects path
# 0    878  413        0  [0]
# 1    228  553        0  [0]
# 2    149  284        0  [0]
# 3   1234   53        0  [0]
# 4   1299  352        0  [0]
# ..   ...  ...      ...  ...
# 95  1371  144        0  [0]
# 96   177  587        0  [0]
# 97   548  658        0  [0]
# 98  1312  293        0  [0]
# 99   930  412        0  [0]
#
# [100 rows x 4 columns]

# %%
# move 
def move(n1, n2):
    
    if n2 == 0:
        nodes.iloc[i, -1] = [0]
    
    
    
move(1,4)

# %%
def get_cost():
    pass

# %%
nodes_array = nodes.values
nodes_array
# Out:
# array([[878, 413, 0, list([0])],
#        [228, 553, 0, list([0])],
#        [149, 284, 0, list([0])],
#        [1234, 53, 0, list([0])],
#        [1299, 352, 0, list([0])],
#        [1028, 418, 0, list([0])],
#        [886, 365, 0, list([0])],
#        [1373, 446, 0, list([0])],
#        [240, 166, 0, list([0])],
#        [423, 620, 0, list([0])],
#        [1312, 692, 0, list([0])],
#        [753, 689, 0, list([0])],
#        [516, 206, 0, list([0])],
#        [332, 580, 0, list([0])],
#        [1156, 537, 0, list([0])],
#        [217, 128, 0, list([0])],
#        [673, 394, 0, list([0])],
#        [1233, 488, 0, list([0])],
#        [346, 343, 0, list([0])],
#        [1261, 4, 0, list([0])],
#        [49, 63, 0, list([0])],
#        [1230, 304, 0, list([0])],
#        [524, 582, 0, list([0])],
#        [770, 458, 0, list([0])],
#        [180, 525, 0, list([0])],
#        [632, 161, 0, list([0])],
#        [1203, 216, 0, list([0])],
#        [593, 429, 0, list([0])],
# ...

# %%
nodes_array[4][2]
# Out:
# 0
